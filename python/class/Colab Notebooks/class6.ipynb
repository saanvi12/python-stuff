# %%
km = int(input("Enter your number in kilometres."))
cm = 100000
print(f"your number in centimetres is {km*cm}")

km = int(input("enter your number in kilometres"))
ft = 3280.84
print(f"your number in feet is {km*ft}") 

km = int(input("enter your number in kilometres"))
inc = 39370.1
print(f"your number in inches is {km*inc}")
# Out:
# Enter your number in kilometres.500
# your number in centimetres is 50000000
# enter your number in kilometres500
# your number in feet is 1640420.0
# enter your number in kilometres500
# your number in inches is 19685050.0

# %%
cel = int(input("Enter the temperature in degrees Celsius"))
fah = 32
print(f"This is the temperature in Celsius: {(cel* 9/5) +32}")
# Out:
# Enter the temperature in degrees Celsius-35
# This is the temperature in Celsius: -31.0

# %%
num1 = int(input("enter your first number here"))
num2 = int(input("enter your second number here"))
num3 = int(input("enter your third number here"))
num4 = int(input("enter your fourth number here"))
num5 = int(input("enter your fifth number here"))
print(f"the average of these five numbers is {num1+ num2 + num3 + num4 + num5}")
# Out:
# enter your first number here4
# enter your second number here76
# enter your third number here56
# enter your fourth number here23
# enter your fifth number here4
# the average of these five numbers is 163

# %%
 varA = 4
 varB = 2
 print(varA)
 print(varB)
 print("now var A is going to become var B")
 temp = varA
varA = varB
varB = temp
print(f"now var A is {varA} and var B is {varB}")
# Out:
# 4
# 2
# now var A is going to become var B
# now var A is 2 and var B is 4

# %%
length = float(input("Enter your first value: "))
width = float(input("Enter your second value: "))
result = length*width
print("Area of a rectangle=length*width")
print(f"Length={length}")
print(f"Width={width}")
print(f"{result} is the area of your rectangle.")
# Out:
# Enter your first value: 45
# Enter your second value: 34
# Area of a rectangle=length*width
# Length=45.0
# Width=34.0
# 1530.0 is the area of your rectangle.

# %%
length = float(input("Enter your first value: "))
width = float(input("Enter your second value: "))
result = 2*(length+width)
print("Perimeter of a rectangle=2(length+width)")
print(f"Length={length}")
print(f"Width={width}")
print(f"{result} is the perimeter of your rectangle.")
# Out:
# Enter your first value: 34
# Enter your second value: 23
# Perimeter of a rectangle=2(length+width)
# Length=34.0
# Width=23.0
# 114.0 is the perimeter of your rectangle.

# %% [markdown]
# #  make this code look nice

# %%
#perimeter of a square. length of one side is the variable "a"
length = float(input("Enter the value of the side length: "))
result = length*4
print("Perimeter of a square= side length * 4")
print(f"{result} is the perimter of the square.")
# Out:
# Enter the value of the side length: 4
# Perimeter of a square= side length * 4
# 16.0 is the perimter of the square.

# %%
#perimeter of a parallelogram 
side = float(input("Enter the value of the side length: "))
base = float(input("Enter the value of the base: "))
res = 2*(side+base)
print("Perimeter of a parallelogram= 2*(side+base)")
print(f"{res} is the perimeter of the parallelogram.")
# Out:
# Enter the value of the side length: 24
# Enter the value of the base: 34
# Perimeter of a parallelogram= 2*(side+base)
# 116.0 is the perimeter of the parallelogram.

# %%
#area of a cirle
pi = 3.14728
rad = float(input("Enter the value of the radius: "))
res = pi*rad**2
print("Area of a circle= pi*rad**2")
print(f"{res} is the area of your circle.")
# Out:
# Enter the value of the radius: 34
# Area of a circle= pi*rad**2
# 3638.2556799999998 is the area of your circle.

# %%
#cricumfgefr of  cricel
pi = 3.14728
rad = float(input("Enter the value of the radius: "))
res = 2*pi*rad
print("Circumference of a circle= 2*pi*rad")
print(f"The circumference of the circle is {res}")
# Out:
# Enter the value of the radius: 7
# Circumference of a circle= 2*pi*rad
# The circumference of the circle is 44.06192

# %%
#perimeter of an equilateral triangle
side = float(input("Enter the value of the side length: "))
res = side*3
print("Perimeter of an equilateral triangle= side*3")
print(f"The perimeter of the equilateral triangle is {res}")
# Out:
# Enter the value of the side length: 10
# Perimeter of an equilateral triangle= side*3
# The perimeter of the equilateral triangle is 30.0

# %%
#perimeter of isosceles
a = float(input("enter the value of the two equal sides: "))
b = float(input("Enter the value of the third side: "))
res = (a*2)+b
print("perimeter of an isosceles triangle= (a*2)+b")
print(f"{res} is the perimeter of the isosceles triangle.")
# Out:
# enter the value of the two equal sides: 24
# Enter the value of the third side: 3
# perimeter of an isosceles triangle= (a*2)+b
# 51.0 is the perimeter of the isosceles triangle.

# %%
#find the third angle
a = int(input("Enter the first angle: "))
b = int(input("Eenter the second angle: "))
c = 180 - (a+b)
print("Third angle= 180-(a+b)")
print(f"The third angle is {c}")
# Out:
# Enter the first angle: 23
# Eenter the second angle: 64
# Third angle= 180-(a+b)
# The third angle is 93
