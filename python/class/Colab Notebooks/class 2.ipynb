# %%
list1 = [1, 2, 3, 4 ,5]
print(sum(list1))
# Out:
# 15

# %%
list1 = [1, 2, 3, 4 ,5]
total = 0
for i in list1:
  total = total+i
  print(total)
print(total)
# Out:
# 1
# 3
# 6
# 10
# 15
# 15

# %%
list1 = [1, 2, 3, 4, 5]
total= 1
for i in list1:
  total = total*i
  print(total)
print(total)
# Out:
# 1
# 2
# 6
# 24
# 120
# 120

# %%
list1 = [1, 2, 3, 4, 5]
num = list1[0]
for i in list1:
  if i>num:
    num=i
print(num)
# Out:
# 5

# %%
list1 = [1, 2, 3, 4, 5]
num = list1[0]
for i in list1:
  if i<num:
    num=i
print(num)
# Out:
# 1

# %%
str1 = ['abc', 'xyz', 'aba', '1221']
for i in str1:
  if len(i)>2:
    print(i)
# Out:
# abc
# xyz
# aba
# 1221

# %%
list1 = [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]
list1.sort(key= lambda list1: list1[1])
print(list1)
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %%
list1 = [1, 2, 3, 2, 4, 3, 1]
list2 = []
for i in list1:
  if i in list2:
    pass
  else:
    list2.append(i)
print(list2)
# Out:
# [1, 2, 3, 4]

# %%
list1 = []
if len(list1)==0:
  print("clear list")
# Out:
# clear list

# %%
list1 = [1,2,3,4]
list2 = []
for i in list1:
  list2.append(i)
print(list2)
# Out:
# [1, 2, 3, 4]

# %%
list1 = ["green", "blue", "red", "pink"]
n = int(input("enter a value:"))
for i in list1:
  if len(i)>n:
    print(i)
# Out:
# enter a value:3
# green
# blue
# pink

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [1, 3, 6, 8, 7]
for i in list1:
  i = 3
  if i == list1 and i==list2:
    print("true")
