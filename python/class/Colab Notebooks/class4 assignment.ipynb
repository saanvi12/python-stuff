# %%
var1 = int(input())
var2 = int(input())
print(var1+var2)
print(var1*var2)
print(var1//var2)
print(var1-var2)
# Out:
# 76
# 25
# 101

# %%
num1 = int(input("Enter a value: "))
num2 = int(input("Enter a value: "))
var1 = "oops"
print("""
    1 - Addition
    2 - Substraction
    3 - Multiplication
    4 - Division
""")
ch = int(input("Enter your choice - "))

if (ch == 1):
    print(f"The result of Addition = {num1 + num2}")
elif (ch == 2):
    print(f"The result of subtraction = {num1 - num2}")
elif (ch == 3):
    print(f"The result of Addition = {num1 + num2}")
elif (ch == 4):
    print(f"The result of Addition = {num1 + num2}")
else:
    print(f"You have entered a wrong Option {var1}!!")
# Out:
# Enter a value: 45678976
# Enter a value: 23
#
#     1 - Addition
#     2 - Substraction
#     3 - Multiplication
#     4 - Division
#
# Enter your choice - 9
# You have entered a wrong Option oops!!

# %%
var1 = int(100)
var2 = int(49)
var3 = int(input("put in a number"))

print(var1%var2)
# Out:
# 2

# %%
var1 = "hi"
var2 = "hello"
print(var1+var2)
# Out:
# hihello

# %%
var1 = "hi"
var2 = "7"
print(var1*var2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4048f349f7e2> in <module>()
#       1 var1 = "hi"
#       2 var2 = "7"
# ----> 3 print(var1*var2)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
var1 = "hi my name"
var2 = " is saanvi"
print(var1+var2)
# Out:
# hi my name is saanvi
