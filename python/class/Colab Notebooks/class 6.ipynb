# %%
tup1 = (1, 2, 3, 3, 4, 5)
list1 = []
for i in tup1:
  if i not in list1:
    list1.append(i)
  else:
    print(i)
# Out:
# 3

# %%
tup1 = (1, 2, 3, 4, 5)
var = 4
for i in tup1:
  if i==var:
    print("it exists!")
  else:
    print("doesn't exist")
tup = (1,2,3,4,5)
a = 3
if a in tup:
    print("It exists")
else:
    print("Iat does not")
# Out:
# doesn't exist
# doesn't exist
# doesn't exist
# it exists!
# doesn't exist

# %%
list1 = [1, 2, 3, 4, 5]
list1 = tuple(list1)
print(type(list1))
print(list1)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)

# %%
tupl1 = (1, 2 ,3 ,4)
tupl1 = list(tupl1)
tupl1.remove(3)
print(tupl1)
# Out:
# [1, 2, 4]

# %%
tup = (1,2,3,4,0)
print(tup[1:2])
# Out:
# (2,)

# %%
tup1 = (1, 2, 3, 4, 5)
print(tup1.index(3))
# Out:
# 2

# %%
print(len(tup1))
# Out:
# 5

# %%
tup1 = (1, 2 ,3 ,4 )
tup1 = list(tup1)
tup1.reverse()
print(tup1)
# Out:
# [4, 3, 2, 1]

# %%
print(f"this is a tuple {tuple(tup1)}")
# Out:
# this is a tuple (4, 3, 2, 1)

# %%
list1 = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
for (i) in list1:
  i

# %%
var = [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), ('d')]
for i in var:
  if len(i)==:
    pass
  else:
    del(i)
print(var)
# Out:
# [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

# %%
list1 = ((10, 10, 10, 12), (30, 45, 56, 45), (81, 80, 39, 32), (1, 2, 3, 4))
listavg = []
for i in list1:
  print(sum(i)/len(i))
# Out:
# 10.5
# 44.0
# 58.0
# 2.5

# %%
tup = ('1', '2', '3')
var = []
for i in tup:
  var.append(int(i))
print(var)
# Out:
# [1, 2, 3]

# %%
tup = (1, 2, 3)
var = []
for i in tup:
  var.append(str(i))
print(''.join(var))
# Out:
# 123
