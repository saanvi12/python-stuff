# %%
list1 = [1, 3, 5, 7]
list2 = [2, 4 ,6 , 8, 9]
print(f"length of list 1 is {len(list1)}")
print(f"length of list 1 is {len(list2)}")
if len(list1) == len(list2):
  print("it is circular")
else:
  pass
print(f"first list's 0 index {list1[0]}")
print(f"first list's 0 index {list2[0]}")
if list1[0] == list2[0]:
  print("it is circular")
else:
  print("no")
# Out:
# length of list 1 is 4
# length of list 1 is 5
# first list's 0 index 1
# first list's 0 index 2
# no

# %%
list1 = [1, 2, 3, 4, 5, 5]
num = list1[0]
for i in list1:
  if i > num:
    num = i
  else:
    pass
print(num)
for i in list1:
  if i < num and i > list1[0] and i>list1[1] and i>list1[2]:
    print(i)
# Out:
# 5
# 4

# %%
vals = [2, 2, 5, 1, 5, 8, 195, 195, 8, 4, 1, 8, 8, 7, 5, 8, 11, 195, 4, 5, 9, 9]
num = []
for i in vals:
  if i not in num:
    num.append(i)
print(num)
num.sort()
print(num)
# Out:
# [2, 5, 1, 8, 195, 4, 7, 11, 9]
# [1, 2, 4, 5, 7, 8, 9, 11, 195]
