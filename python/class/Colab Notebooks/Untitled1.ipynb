# %%
var= "James Bond"
print(var[2::-1])
# Out:
# maJ

# %%
for x in range(0.5, 5.5, 0.5):
  print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a83c9de7c4f1> in <module>()
# ----> 1 for x in range(0.5, 5.5, 0.5):
#       2   print(x)
#       3
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
a = [10, 20]
b = a
b += [30, 40]
print(a)
print(b)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
x = float('NaN')
print('%f, %e, %F, %E' % (x, x, x, x))
# Out:
# nan, nan, NAN, NAN
