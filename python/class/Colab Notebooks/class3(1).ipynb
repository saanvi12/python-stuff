# %%
var1=10
var2=11
print(id(var1))
print(id(var2))
# Out:
# 10914784
# 10914816

# %%
var1 is var2
# Out:
# False

# %%
var1 is not var2
# Out:
# True

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
fname = input("enter your first name")
lname = input("enter your last name")
age = int(input())
if age >= 15 and age <= 20:
  print("f{fname} you are betweeen 15 and 20")
else:
  print(f"sorry {fname} you are too old/young.")
# Out:
# enter your first namesaanvi
# enter your last namemogla
# 13
# sorry saanvi you are too old/young.

# %% [markdown]
# Step 1: Start
#
# Step 2: [ Take Input ] Read: Number
#
# Step 3: Check: If Number%2 == 0 Then
#
# Print : N is an Even Number.
#
# Else
#
# Print : N is an Odd Number.
#
# Step 4: Exit

# %%
var1 = 
input(int("enter a n"))
# Out:
# enter your ageughrfbe
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-8568691cbb51> in <module>()
#       1
# ----> 2 int(input("enter your age"))
#
# ValueError: invalid literal for int() with base 10: 'ughrfbe'
