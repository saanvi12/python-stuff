# %%
var1 = int(input("enter number of kilometres"))
print(var1 * 10000 )
print("now you have it in centimetres")
# Out:
# enter number of kilometres25
# 250000
# now you have it in centimetres)

# %%
var1 = int(input("enter number of kilometres"))
var2 = int(3280.84)
print(var1 * var2)
print("now you have it in feet")
# Out:
# enter number of kilometres25
# 82000
# now you have it in feet

# %%
var1 = int(input("enter number of kilometres"))
var2 = int(39370)
print(var1 * var2)
print("now you have it in inches")
# Out:
# enter number of kilometres65
# 2559050
# now you have it in inches

# %%
var1 = int(input("enter celsius degree"))
var2 = int(32)
print(var1 * var2)
print("now you have it in fahrenheit")
# Out:
# enter celsius degree-45
# -1440
# now you have it in fahrenheit

# %%
var1= int(input("put in a number here "))
var2= int(input("put in a number here "))
var3= int(input("put in a number here "))
var4= int(input("put in a number here "))
var5= int(input("put in a number here "))
print((var1 + var2 + var3 + var4 + var5)/5 )
# Out:
# put in a number here 34
# put in a number here 34
# put in a number here 34
# put in a number here 34
# put in a number here 34
# 34.0

# %%
var1 = 25
var2 = 30
temp = var1
var1 = var2
var2 = temp
print(f"the value of var 1 after switching: {var1}")
print(f"the value of var 2 after switching: {var2}")
# Out:
# the value of var 1 after switching: 30
# the value of var 2 after switching: 25
